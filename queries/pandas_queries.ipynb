# %%
import pandas as pd

# %%
# amy's list
files = ["../../zq-sample-data/zeek-ndjson/" + i 
         for i in [ "conn.ndjson",
                    "http.ndjson",
                    "files.ndjson",
                    "dns.ndjson",
                    "ssl.ndjson",
                    "weird.ndjson",
                    "syslog.ndjson",
                    "rdp.ndjson",
                    "ntp.ndjson",
                    "smtp.ndjson"]
        ]

# %%
dfs = [pd.read_json(f, lines=True) for f in files]

# %% [markdown]
# ### Analytics queries

# %% [markdown]
# I. Count total number of records with each distinct source IP

# %%
_field = "id.orig_h"
pd.concat([f[[_field]] for f in dfs 
           if _field in f.columns]) \
  .groupby(_field)\
  .size()\
  .reset_index(name='count')
# Out:
#                     id.orig_h  count
# 0                  10.0.0.111   4044
# 1                  10.0.0.205     38
# 2                  10.0.0.208     81
# 3                  10.0.0.219    126
# 4                  10.0.0.227  54439
# ..                        ...    ...
# 659              172.30.255.2     19
# 660              172.31.255.3    200
# 661              172.31.255.5   2507
# 662              204.42.254.5      1
# 663  fe80::215:17ff:fe84:c13f      1
#
# [664 rows x 2 columns]

# %% [markdown]
# ### Search queries

# %% [markdown]
# I. Find all records with IP 10.128.0.19, sort by timestamp, and return the first 5

# %%
# records in a single dataframe
_dfs = pd.concat([f for f in dfs 
           if _field in f.columns], sort=False)
_dfs[_dfs["id.orig_h"] == "10.128.0.19"].sort_values("ts").head(5)
# Out:
#        _path                    _write_ts                           ts  \
# 19940   conn  2018-03-24T17:15:46.403161Z  2018-03-24T17:15:22.405489Z
# 105     http  2018-03-24T17:15:22.433287Z  2018-03-24T17:15:22.409738Z
# 182092  conn  2018-03-24T17:18:18.377152Z  2018-03-24T17:17:22.470658Z
# 13900   http  2018-03-24T17:17:22.502126Z  2018-03-24T17:17:22.474844Z
# 494741  conn  2018-03-24T17:24:29.273572Z  2018-03-24T17:19:23.463206Z
#
#                        uid    id.orig_h  id.orig_p     id.resp_h  id.resp_p  \
# 19940   C4XMvY3AbHWJ1ejqyd  10.128.0.19    58563.0  10.47.27.186       80.0
# 105     C4XMvY3AbHWJ1ejqyd  10.128.0.19    58563.0  10.47.27.186       80.0
# 182092   CxU6Zp2LgS9Dn0Zw2  10.128.0.19    58604.0  10.47.27.186       80.0
# 13900    CxU6Zp2LgS9Dn0Zw2  10.128.0.19    58604.0  10.47.27.186       80.0
# 494741  CEX5va1wKylFQqaKC7  10.128.0.19    58641.0  10.47.27.186       80.0
#
#        proto   duration  ...  xmt_time  num_exts helo  last_reply path  tls  \
# 19940    tcp  18.997580  ...       NaT       NaN  NaN         NaN  NaN  NaN
# 105      NaN        NaN  ...       NaT       NaN  NaN         NaN  NaN  NaN
# 182092   tcp  50.906348  ...       NaT       NaN  NaN         NaN  NaN  NaN
# 13900    NaN        NaN  ...       NaT       NaN  NaN         NaN  NaN  NaN
# 494741   tcp   5.810212  ...       NaT       NaN  NaN         NaN  NaN  NaN
#
#         fuids  is_webmail  mailfrom rcptto
# 19940     NaN         NaN       NaN    NaN
# 105       NaN         NaN       NaN    NaN
# 182092    NaN         NaN       NaN    NaN
# 13900     NaN         NaN       NaN    NaN
# 494741    NaN         NaN       NaN    NaN
#
# [5 rows x 116 columns]

# %%
# records as dataframes
def search(field, label, key, n):
    rows, results = list(), list()
    for f in dfs:
        if field in f.columns:
            rows += f[f[field] == label].iterrows()

    return sorted(rows, key=lambda x: x[1][key])[:n]

records = search("id.orig_h", "10.128.0.19", "ts", 5)
for r in records:
    display(r[1].to_frame().transpose())
# Out:
#       _path                    _write_ts                           ts  \
# 19940  conn  2018-03-24T17:15:46.403161Z  2018-03-24T17:15:22.405489Z
#
#                       uid    id.orig_h id.orig_p     id.resp_h id.resp_p  \
# 19940  C4XMvY3AbHWJ1ejqyd  10.128.0.19     58563  10.47.27.186        80
#
#       proto duration orig_bytes resp_bytes conn_state missed_bytes  \
# 19940   tcp  18.9976       1303        544         SF            0
#
#           history orig_pkts orig_ip_bytes resp_pkts resp_ip_bytes service
# 19940  ShADTadtfF        12          3254        10          1624    http
#     _path                    _write_ts                           ts  \
# 105  http  2018-03-24T17:15:22.433287Z  2018-03-24T17:15:22.409738Z
#
#                     uid    id.orig_h id.orig_p     id.resp_h id.resp_p  \
# 105  C4XMvY3AbHWJ1ejqyd  10.128.0.19     58563  10.47.27.186        80
#
#     trans_depth method  ... resp_mime_types  \
# 105           1   POST  ...     [text/json]
#
#                                               referrer            orig_fuids  \
# 105  http://10.47.27.186/wordpress/wp-admin/theme-e...  [FJWmvt4dKqo4Q0iFxd]
#
#     orig_mime_types               origin proxied resp_filenames username  \
# 105    [text/plain]  http://10.47.27.186     NaN            NaN      NaN
#
#     info_code info_msg
# 105       NaN      NaN
#
# [1 rows x 30 columns]
#        _path                    _write_ts                           ts  \
# 182092  conn  2018-03-24T17:18:18.377152Z  2018-03-24T17:17:22.470658Z
#
#                       uid    id.orig_h id.orig_p     id.resp_h id.resp_p  \
# 182092  CxU6Zp2LgS9Dn0Zw2  10.128.0.19     58604  10.47.27.186        80
#
#        proto duration orig_bytes resp_bytes conn_state missed_bytes  \
# 182092   tcp  50.9063       1303        544         SF            0
#
#            history orig_pkts orig_ip_bytes resp_pkts resp_ip_bytes service
# 182092  ShADTadtfF        14          3334        12          1728    http
#       _path                    _write_ts                           ts  \
# 13900  http  2018-03-24T17:17:22.502126Z  2018-03-24T17:17:22.474844Z
#
#                      uid    id.orig_h id.orig_p     id.resp_h id.resp_p  \
# 13900  CxU6Zp2LgS9Dn0Zw2  10.128.0.19     58604  10.47.27.186        80
#
#       trans_depth method  ... resp_mime_types  \
# 13900           1   POST  ...     [text/json]
#
#                                                 referrer           orig_fuids  \
# 13900  http://10.47.27.186/wordpress/wp-admin/theme-e...  [F9FLRlKCsMHV92CM3]
#
#       orig_mime_types               origin proxied resp_filenames username  \
# 13900    [text/plain]  http://10.47.27.186     NaN            NaN      NaN
#
#       info_code info_msg
# 13900       NaN      NaN
#
# [1 rows x 30 columns]
#        _path                    _write_ts                           ts  \
# 494741  conn  2018-03-24T17:24:29.273572Z  2018-03-24T17:19:23.463206Z
#
#                        uid    id.orig_h id.orig_p     id.resp_h id.resp_p  \
# 494741  CEX5va1wKylFQqaKC7  10.128.0.19     58641  10.47.27.186        80
#
#        proto duration orig_bytes resp_bytes conn_state missed_bytes  \
# 494741   tcp  5.81021       1303        544         S3            0
#
#           history orig_pkts orig_ip_bytes resp_pkts resp_ip_bytes service
# 494741  ShADTadtf        14          3358        12          1728    http

# %% [markdown]
# ### Data discovery queries

# %% [markdown]
# I. Count the number of records with each different schema

# %%
for df in dfs:
    print(df.dtypes, len(df))
# Out:
# _path             object
# _write_ts         object
# ts                object
# uid               object
# id.orig_h         object
# id.orig_p          int64
# id.resp_h         object
# id.resp_p          int64
# proto             object
# duration         float64
# orig_bytes       float64
# resp_bytes       float64
# conn_state        object
# missed_bytes       int64
# history           object
# orig_pkts          int64
# orig_ip_bytes      int64
# resp_pkts          int64
# resp_ip_bytes      int64
# service           object
# dtype: object 1021952
# _path                 object
# _write_ts             object
# ts                    object
# uid                   object
# id.orig_h             object
# id.orig_p              int64
# id.resp_h             object
# id.resp_p              int64
# trans_depth            int64
# method                object
# host                  object
# uri                   object
# version              float64
# user_agent            object
# request_body_len       int64
# response_body_len      int64
# status_code          float64
# status_msg            object
# tags                  object
# resp_fuids            object
# resp_mime_types       object
# referrer              object
# orig_fuids            object
# orig_mime_types       object
# origin                object
# proxied               object
# resp_filenames        object
# username              object
# info_code            float64
# info_msg              object
# dtype: object 144034
# _path              object
# _write_ts          object
# ts                 object
# fuid               object
# tx_hosts           object
# rx_hosts           object
# conn_uids          object
# source             object
# depth               int64
# analyzers          object
# mime_type          object
# duration          float64
# is_orig              bool
# seen_bytes          int64
# total_bytes       float64
# missing_bytes       int64
# overflow_bytes      int64
# timedout             bool
# md5                object
# sha1               object
# filename           object
# dtype: object 162986
# _path           object
# _write_ts       object
# ts              object
# uid             object
# id.orig_h       object
# id.orig_p        int64
# id.resp_h       object
# id.resp_p        int64
# proto           object
# trans_id         int64
# rtt            float64
# query           object
# qclass         float64
# qclass_name     object
# qtype          float64
# qtype_name      object
# rcode          float64
# rcode_name      object
# AA                bool
# TC                bool
# RD                bool
# RA                bool
# Z                int64
# answers         object
# TTLs            object
# rejected          bool
# dtype: object 53615
# _path                      object
# _write_ts                  object
# ts                         object
# uid                        object
# id.orig_h                  object
# id.orig_p                   int64
# id.resp_h                  object
# id.resp_p                   int64
# version                    object
# cipher                     object
# curve                      object
# resumed                      bool
# established                  bool
# cert_chain_fuids           object
# client_cert_chain_fuids    object
# subject                    object
# issuer                     object
# validation_status          object
# server_name                object
# next_protocol              object
# last_alert                 object
# client_subject             object
# client_issuer              object
# dtype: object 35493
# _path         object
# _write_ts     object
# ts            object
# uid           object
# id.orig_h     object
# id.orig_p    float64
# id.resp_h     object
# id.resp_p    float64
# name          object
# notice          bool
# peer          object
# addl          object
# dtype: object 24048
# _path        object
# _write_ts    object
# ts           object
# uid          object
# id.orig_h    object
# id.orig_p     int64
# id.resp_h    object
# id.resp_p     int64
# proto        object
# facility     object
# severity     object
# message      object
# dtype: object 2378
# _path                     object
# _write_ts                 object
# ts                        object
# uid                       object
# id.orig_h                 object
# id.orig_p                  int64
# id.resp_h                 object
# id.resp_p                  int64
# result                    object
# security_protocol         object
# cert_count                 int64
# cert_type                 object
# cert_permanent           float64
# encryption_level          object
# encryption_method         object
# cookie                    object
# client_channels           object
# keyboard_layout           object
# client_build              object
# client_name               object
# client_dig_product_id     object
# desktop_width            float64
# desktop_height           float64
# requested_color_depth     object
# dtype: object 4122
# _path                      object
# _write_ts                  object
# ts                         object
# uid                        object
# id.orig_h                  object
# id.orig_p                   int64
# id.resp_h                  object
# id.resp_p                   int64
# version                     int64
# mode                        int64
# stratum                     int64
# poll                        int64
# precision                 float64
# root_delay                float64
# root_disp                 float64
# ref_id                     object
# ref_time      datetime64[ns, UTC]
# org_time      datetime64[ns, UTC]
# rec_time      datetime64[ns, UTC]
# xmt_time      datetime64[ns, UTC]
# num_exts                    int64
# dtype: object 904
# _path          object
# _write_ts      object
# ts             object
# uid            object
# id.orig_h      object
# id.orig_p       int64
# id.resp_h      object
# id.resp_p       int64
# trans_depth     int64
# helo           object
# last_reply     object
# path           object
# tls              bool
# fuids          object
# is_webmail       bool
# mailfrom       object
# rcptto         object
# dtype: object 1188
